# %%
from qiskit import QuantumCircuit
qasm = """
OPENQASM 2.0;
include "qelib1.inc";
gate rzx(param0) q0,q1 { h q1; cx q0,q1; rz(param0) q1; cx q0,q1; h q1; }
gate ecr q0,q1 { rzx(pi/4) q0,q1; x q0; rzx(-pi/4) q0,q1; }
qreg q[127];
creg c[4];
rz(pi/2) q[24];
sx q[24];
rz(-pi/2) q[25];
sx q[25];
rz(-pi) q[25];
rz(-pi) q[26];
sx q[26];
ecr q[25],q[26];
rz(-pi/2) q[25];
sx q[25];
rz(3*pi/4) q[25];
sx q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
rz(-pi/4) q[25];
sx q[25];
rz(-pi) q[25];
sx q[26];
ecr q[25],q[26];
rz(-pi/2) q[25];
sx q[25];
rz(3*pi/4) q[25];
sx q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
x q[25];
rz(pi/4) q[25];
rz(-pi/2) q[26];
sx q[26];
rz(pi/4) q[26];
ecr q[25],q[26];
rz(pi/2) q[25];
sx q[25];
rz(-pi) q[26];
sx q[26];
rz(pi/2) q[26];
ecr q[25],q[26];
rz(-pi/2) q[25];
sx q[25];
sx q[26];
rz(-pi/2) q[26];
ecr q[25],q[26];
rz(pi/2) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/4) q[24];
rz(3*pi/4) q[25];
sx q[25];
rz(-pi) q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
rz(pi/2) q[25];
sx q[25];
rz(-pi) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
rz(-pi/2) q[25];
rz(pi/2) q[26];
sx q[26];
rz(0.8198197080448963) q[26];
sx q[26];
ecr q[25],q[26];
x q[25];
rz(-pi/2) q[25];
rz(2.390616034839793) q[26];
sx q[26];
rz(-pi) q[26];
ecr q[25],q[26];
rz(pi/2) q[25];
sx q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
sx q[26];
rz(pi/2) q[26];
ecr q[25],q[26];
rz(pi/2) q[25];
sx q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
rz(3*pi/4) q[26];
sx q[26];
rz(-pi) q[26];
ecr q[25],q[26];
rz(pi/2) q[25];
sx q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
rz(-3*pi/4) q[26];
sx q[26];
rz(-pi) q[26];
ecr q[25],q[26];
rz(-pi/4) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-pi/2) q[24];
rz(3*pi/4) q[26];
sx q[26];
rz(-pi) q[26];
ecr q[25],q[26];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(pi/4) q[24];
sx q[24];
rz(pi/2) q[25];
sx q[25];
rz(-3*pi/4) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-0.5438180812500004) q[24];
sx q[24];
sx q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(0.54381808125) q[24];
sx q[24];
sx q[25];
ecr q[24],q[25];
sx q[24];
rz(pi/2) q[24];
sx q[25];
rz(-pi/4) q[26];
sx q[26];
rz(1.8110488080448963) q[26];
sx q[26];
rz(-pi) q[34];
sx q[34];
ecr q[24],q[34];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[34];
sx q[34];
rz(pi/2) q[34];
ecr q[24],q[34];
rz(-pi/2) q[24];
sx q[24];
sx q[34];
rz(-pi/2) q[34];
ecr q[24],q[34];
rz(-pi/2) q[24];
sx q[24];
rz(0.3292824687500002) q[24];
sx q[24];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-0.3292824687499998) q[24];
sx q[24];
sx q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-pi) q[24];
ecr q[24],q[34];
rz(-pi/2) q[24];
sx q[24];
rz(pi/4) q[24];
sx q[24];
rz(-pi/2) q[25];
sx q[25];
ecr q[25],q[26];
x q[25];
rz(-pi/2) q[25];
rz(-2.9013401723397934) q[26];
sx q[26];
rz(-pi) q[26];
ecr q[25],q[26];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-pi/4) q[24];
sx q[24];
sx q[25];
sx q[26];
rz(-pi/2) q[26];
sx q[34];
ecr q[24],q[34];
rz(-pi/2) q[24];
sx q[24];
rz(pi/4) q[24];
sx q[24];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(3*pi/4) q[24];
x q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(pi/2) q[24];
rz(pi/2) q[25];
sx q[25];
rz(1.4001419705448965) q[25];
sx q[25];
rz(pi/2) q[34];
sx q[34];
rz(pi/4) q[34];
sx q[34];
ecr q[24],q[34];
x q[24];
rz(-pi/4) q[24];
rz(3*pi/4) q[34];
sx q[34];
rz(-pi) q[34];
ecr q[24],q[34];
x q[24];
rz(-pi/2) q[24];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
rz(2.970938297339793) q[25];
sx q[25];
rz(-pi) q[25];
ecr q[24],q[25];
sx q[24];
rz(pi/2) q[25];
sx q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
x q[24];
sx q[34];
rz(-pi/2) q[34];
ecr q[24],q[34];
rz(-pi/2) q[24];
sx q[24];
rz(pi/4) q[24];
sx q[24];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-pi/4) q[24];
sx q[24];
sx q[25];
sx q[34];
ecr q[24],q[34];
rz(-pi/2) q[24];
sx q[24];
rz(pi/4) q[24];
sx q[24];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-pi/4) q[24];
sx q[24];
rz(pi/2) q[24];
x q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(pi/2) q[24];
sx q[25];
rz(pi/2) q[34];
sx q[34];
rz(pi/4) q[34];
sx q[34];
ecr q[24],q[34];
x q[24];
rz(-pi/4) q[24];
rz(3*pi/4) q[34];
sx q[34];
rz(-pi) q[34];
ecr q[24],q[34];
sx q[24];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
x q[24];
sx q[34];
rz(-pi/2) q[34];
ecr q[24],q[34];
rz(-pi/2) q[24];
sx q[24];
rz(pi/4) q[24];
sx q[24];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-pi/4) q[24];
sx q[24];
sx q[25];
sx q[34];
ecr q[24],q[34];
rz(-pi/2) q[24];
sx q[24];
rz(pi/4) q[24];
sx q[24];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-pi/4) q[24];
sx q[24];
rz(pi/2) q[24];
x q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(pi/2) q[24];
rz(-pi) q[25];
x q[25];
ecr q[25],q[26];
rz(-pi/2) q[25];
sx q[25];
rz(3*pi/4) q[25];
sx q[25];
sx q[26];
rz(pi/2) q[34];
sx q[34];
rz(pi/4) q[34];
sx q[34];
ecr q[24],q[34];
x q[24];
rz(-pi/4) q[24];
rz(3*pi/4) q[34];
sx q[34];
rz(-pi) q[34];
ecr q[24],q[34];
x q[24];
rz(-pi/2) q[24];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
rz(-pi/4) q[25];
sx q[25];
rz(-pi) q[25];
ecr q[25],q[26];
rz(-pi/2) q[25];
sx q[25];
rz(3*pi/4) q[25];
sx q[25];
ecr q[24],q[25];
rz(-pi) q[24];
x q[24];
rz(pi/4) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-1.4195575955448967) q[24];
sx q[24];
rz(pi/2) q[26];
sx q[26];
rz(pi/4) q[26];
sx q[26];
ecr q[25],q[26];
x q[25];
rz(-pi/4) q[25];
rz(3*pi/4) q[26];
sx q[26];
rz(-pi) q[26];
ecr q[25],q[26];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-0.1512387312500003) q[24];
sx q[24];
sx q[25];
ecr q[24],q[25];
rz(-pi) q[24];
sx q[24];
rz(pi/2) q[24];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[25];
sx q[25];
rz(pi/2) q[25];
sx q[26];
rz(-pi/2) q[26];
ecr q[25],q[26];
rz(-pi/2) q[25];
sx q[25];
rz(3*pi/4) q[25];
sx q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
rz(-pi/4) q[25];
sx q[25];
rz(-pi) q[25];
sx q[26];
ecr q[25],q[26];
rz(-pi/2) q[25];
sx q[25];
rz(3*pi/4) q[25];
sx q[25];
ecr q[24],q[25];
sx q[24];
rz(-pi/4) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[25];
sx q[25];
rz(pi/2) q[25];
rz(pi/2) q[26];
sx q[26];
rz(pi/4) q[26];
sx q[26];
ecr q[25],q[26];
x q[25];
rz(-pi/4) q[25];
rz(3*pi/4) q[26];
sx q[26];
rz(-pi) q[26];
ecr q[25],q[26];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
sx q[26];
rz(-pi/2) q[26];
sx q[34];
rz(-pi/2) q[34];
ecr q[24],q[34];
rz(-pi/2) q[24];
sx q[24];
rz(pi/4) q[24];
sx q[24];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-pi/4) q[24];
sx q[24];
sx q[25];
sx q[34];
ecr q[24],q[34];
rz(-pi/2) q[24];
sx q[24];
rz(pi/4) q[24];
sx q[24];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(-pi/4) q[24];
sx q[24];
rz(pi/2) q[24];
x q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(pi/2) q[24];
rz(-pi) q[25];
x q[25];
ecr q[25],q[26];
rz(-pi/2) q[25];
sx q[25];
rz(3*pi/4) q[25];
sx q[25];
sx q[26];
rz(pi/2) q[34];
sx q[34];
rz(pi/4) q[34];
sx q[34];
ecr q[24],q[34];
x q[24];
rz(-pi/4) q[24];
rz(3*pi/4) q[34];
sx q[34];
rz(-pi) q[34];
ecr q[24],q[34];
x q[24];
rz(-pi/2) q[24];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
rz(-pi/4) q[25];
sx q[25];
rz(-pi) q[25];
ecr q[25],q[26];
rz(-pi/2) q[25];
sx q[25];
rz(3*pi/4) q[25];
sx q[25];
ecr q[24],q[25];
rz(-pi) q[24];
x q[24];
rz(pi/4) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-1.6167811455448962) q[24];
sx q[24];
rz(pi/2) q[26];
sx q[26];
rz(pi/4) q[26];
sx q[26];
ecr q[25],q[26];
x q[25];
rz(-pi/4) q[25];
rz(3*pi/4) q[26];
sx q[26];
rz(-pi) q[26];
ecr q[25],q[26];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
rz(0.0459848187499996) q[24];
sx q[24];
sx q[25];
ecr q[24],q[25];
rz(-pi) q[24];
sx q[24];
rz(pi/2) q[24];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[25];
sx q[25];
rz(pi/2) q[25];
sx q[26];
rz(-pi/2) q[26];
ecr q[25],q[26];
rz(-pi/2) q[25];
sx q[25];
rz(3*pi/4) q[25];
sx q[25];
ecr q[24],q[25];
x q[24];
rz(-pi/2) q[24];
rz(-pi/4) q[25];
sx q[25];
rz(-pi) q[25];
sx q[26];
ecr q[25],q[26];
rz(-pi/2) q[25];
sx q[25];
rz(3*pi/4) q[25];
sx q[25];
ecr q[24],q[25];
rz(-pi) q[24];
x q[24];
rz(pi/4) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
rz(-pi/2) q[24];
sx q[24];
sx q[25];
rz(-pi/2) q[25];
ecr q[24],q[25];
rz(pi/2) q[24];
sx q[24];
rz(-pi) q[25];
sx q[25];
rz(pi/2) q[25];
ecr q[24],q[25];
x q[24];
rz(pi/2) q[26];
sx q[26];
rz(pi/4) q[26];
sx q[26];
ecr q[25],q[26];
x q[25];
rz(-pi/4) q[25];
rz(3*pi/4) q[26];
sx q[26];
rz(-pi) q[26];
ecr q[25],q[26];
rz(0.14074838304489568) q[25];
sx q[25];
rz(-pi) q[25];
barrier q[25],q[34],q[26],q[24];
measure q[25] -> c[0];
measure q[34] -> c[1];
measure q[26] -> c[2];
measure q[24] -> c[3];
"""
circuit = QuantumCircuit.from_qasm_str(qasm)

# %%
from collections import Counter
gate_map = Counter()
for gate in circuit.data:
    gate_map[gate[0].name] += 1

# %% [markdown]
# <h2>Decreasing coefficient ordering</h2>

# %%
print(gate_map)
# Out:
# Counter({'rz': 333, 'sx': 251, 'ecr': 131, 'x': 42, 'measure': 4, 'barrier': 1})

# %%
print(circuit.depth())
# Out:
# 482

# %% [markdown]
# <h2>Gray code ordering</h2>

# %%
print(gate_map)
# Out:
# Counter({'rz': 212, 'sx': 153, 'ecr': 77, 'x': 20, 'measure': 4, 'barrier': 1})

# %%
print(circuit.depth())
# Out:
# 303
